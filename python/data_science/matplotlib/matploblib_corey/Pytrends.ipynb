# %%
import matplotlib.pyplot as plt
from pytrends.request import TrendReq
pytrends = TrendReq(hl = 'en-US')
keywords = ['Python', 'JavaScript', 'Java', 'HTML', 'C++']
pytrends.build_payload(keywords, timeframe = 'today 5-y')

# %%
data = pytrends.interest_over_time()
data
# Out:
#             Python  JavaScript  Java  HTML  C++  isPartial
# date
# 2017-09-17      20          12    30    15   78      False
# 2017-09-24      20          12    31    16   80      False
# 2017-10-01      20          12    29    15   77      False
# 2017-10-08      21          12    31    15   80      False
# 2017-10-15      20          12    29    15   77      False
# ...            ...         ...   ...   ...  ...        ...
# 2022-08-07      33          11    23    13   91      False
# 2022-08-14      32          11    23    13   82      False
# 2022-08-21      34          12    24    13   88      False
# 2022-08-28      31          12    23    13   87      False
# 2022-09-04      33          11    25    14   88      False
#
# [260 rows x 6 columns]

# %%
plt.plot(data)
plt.suptitle('Interest in Programming Languages(2018-2022)')
plt.xlabel('Years')
plt.ylabel('Level of Interest')
plt.legend(keywords, loc = 'best')
plt.tight_layout()
plt.show()

# %%
focus = ['JavaScript', 'Python', 'C++']
plt.plot(data[focus])
plt.legend(focus)

# %%
data2 = pytrends.interest_by_region(resolution = 'COUNTRY', inc_low_vol = True)
data3 = data2['Python'].nlargest(10)
data3
# Out:
# geoName
# China          50
# Israel         38
# Eritrea        36
# St. Helena     33
# Singapore      31
# Iceland        28
# South Korea    28
# Russia         27
# Hong Kong      26
# Norway         26
# Name: Python, dtype: int32

# %%
data3 = data3.to_frame()
data3
# Out:
#              Python
# geoName
# China            50
# Israel           38
# Eritrea          36
# St. Helena       33
# Singapore        31
# Iceland          28
# South Korea      28
# Russia           27
# Hong Kong        26
# Norway           26

# %%
data3.plot(kind = 'bar')
# Out:
# <AxesSubplot:xlabel='geoName'>

# %%
data4 = data2[120:125]
data4
# Out:
#          Python  JavaScript  Java  HTML  C++
# geoName
# Laos         12           8    20    10   50
# Latvia       15          10    19    13   43
# Lebanon      14           8    15    10   53
# Lesotho       9           4    15    13   59
# Liberia       3           2    11     5   79

# %%
data4.plot(kind = 'bar')
# Out:
# <AxesSubplot:xlabel='geoName'>
