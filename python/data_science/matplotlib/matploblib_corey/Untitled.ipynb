# %%
import matplotlib.pyplot as plt
from pytrends.request import TrendReq
pytrends = TrendReq(hl = 'en-US')
keywords = ['basket', 'tennis']
pytrends.build_payload(keywords, timeframe = 'today 5-y')

# %%
data = pytrends.interest_over_time()
data
# Out:
#             basket  tennis  isPartial
# date
# 2017-09-24      17      23      False
# 2017-10-01      17      26      False
# 2017-10-08      18      27      False
# 2017-10-15      17      26      False
# 2017-10-22      17      25      False
# ...            ...     ...        ...
# 2022-08-21      19      32      False
# 2022-08-28      21      70      False
# 2022-09-04      24      84      False
# 2022-09-11      28      36      False
# 2022-09-18      29      26       True
#
# [261 rows x 3 columns]

# %%
plt.plot(data)
plt.suptitle('Interest in Programming Languages(2018-2022)')
plt.xlabel('Years')
plt.ylabel('Level of Interest')
plt.legend(keywords, loc = 'best')
plt.tight_layout()
plt.show()
