# %%
import pandas as pd
import numpy as np
df = pd.read_csv('survey_results_public.csv')
pd.set_option('display.max_columns', 78)
schema = pd.read_csv('survey_results_schema.csv', index_col = 'qname')
pd.set_option('display.max_rows', 78)
df.head(3)
# Out:
#    ResponseId                                         MainBranch  \
# 0           1                                      None of these
# 1           2                     I am a developer by profession
# 2           3  I am not primarily a developer, but I write co...
#
#             Employment                            RemoteWork  \
# 0                  NaN                                   NaN
# 1  Employed, full-time                          Fully remote
# 2  Employed, full-time  Hybrid (some remote, some in-person)
#
#                            CodingActivities  \
# 0                                       NaN
# 1  Hobby;Contribute to open-source projects
# 2                                     Hobby
#
#                                            EdLevel  \
# 0                                              NaN
# 1                                              NaN
# 2  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
#
#                                            LearnCode  \
# ...

# %%
schema.sort_index().head(50)
# Out:
#                          qid  \
# qname
# Accessibility         QID124
# Age                   QID127
# Blockchain            QID305
# BuyNewTool            QID279
# CodingActivities      QID297
# CompFreq               QID52
# CompTotal              QID51
# Country                 QID6
# Currency               QID50
# Database              QID262
# DevType                QID31
# EdLevel                QID25
# Employment            QID296
# Ethnicity             QID126
# Frequency             QID290
# Frequency_1           QID290
# Frequency_2           QID290
# Frequency_3           QID290
# Gender                QID122
# ICorPM                QID287
# Knowledge             QID289
# Knowledge_1           QID289
# Knowledge_2           QID289
# Knowledge_3           QID289
# Knowledge_4           QID289
# Knowledge_5           QID289
# Knowledge_6           QID289
# Knowledge_7           QID289
# Language              QID233
# LearnCode             QID276
# ...

# %%
df.loc[1, 'RemoteWork']
# Out:
# 'Fully remote'

# %%
countries = ['Canada', 'Viet Nam']
filt = df['Country'].isin(countries)
df.loc[filt, ['Gender', 'Sexuality']]
# Out:
#       Gender                Sexuality
# 1        NaN                      NaN
# 22       Man  Straight / Heterosexual
# 32       Man  Straight / Heterosexual
# 36       Man  Straight / Heterosexual
# 60       Man  Straight / Heterosexual
# ...      ...                      ...
# 73082    Man  Straight / Heterosexual
# 73087    Man  Straight / Heterosexual
# 73110  Woman  Straight / Heterosexual
# 73123    Man  Straight / Heterosexual
# 73267    Man  Straight / Heterosexual
#
# [2807 rows x 2 columns]

# %%
filt2 = df['Sexuality'].str.contains('Gay', na = False)
df.loc[filt2, 'Country'].value_counts().head(15)
# Out:
# United States of America                                465
# Germany                                                 168
# United Kingdom of Great Britain and Northern Ireland    160
# Brazil                                                   88
# Canada                                                   70
# France                                                   64
# Australia                                                55
# Netherlands                                              42
# Spain                                                    39
# Italy                                                    38
# Poland                                                   33
# China                                                    30
# Russian Federation                                       28
# Israel                                                   23
# India                                                    23
# Name: Country, dtype: int64

# %%
[x.upper() for x in schema.columns]
# Out:
# ['QID', 'QUESTION', 'FORCE_RESP', 'TYPE', 'SELECTOR']

# %%
schema.columns = schema.columns.str.replace('question','Question')
schema
# Out:
#                 qid                                           Question  \
# qname
# S0            QID16  <div><span style="font-size:19px;"><strong>Hel...
# MetaInfo      QID12                                  Browser Meta Info
# S1             QID1  <span style="font-size:22px; font-family: aria...
# MainBranch     QID2  Which of the following options best describes ...
# Employment   QID296  Which of the following best describes your cur...
# ...             ...                                                ...
# Frequency_2  QID290  Interacting with people outside of your immedi...
# Frequency_3  QID290  Encountering knowledge silos (where one indivi...
# TrueFalse_1  QID294  Are you involved in supporting new hires durin...
# TrueFalse_2  QID294  Do you use learning resources provided by your...
# TrueFalse_3  QID294  Does your employer give you time to learn new ...
#
#             force_resp  type selector
# qname
# S0               False    DB       TB
# ...

# %%
schema.columns = schema.columns.str.upper()
schema
# Out:
#                 QID                                           QUESTION  \
# qname
# S0            QID16  <div><span style="font-size:19px;"><strong>Hel...
# MetaInfo      QID12                                  Browser Meta Info
# S1             QID1  <span style="font-size:22px; font-family: aria...
# MainBranch     QID2  Which of the following options best describes ...
# Employment   QID296  Which of the following best describes your cur...
# ...             ...                                                ...
# Frequency_2  QID290  Interacting with people outside of your immedi...
# Frequency_3  QID290  Encountering knowledge silos (where one indivi...
# TrueFalse_1  QID294  Are you involved in supporting new hires durin...
# TrueFalse_2  QID294  Do you use learning resources provided by your...
# TrueFalse_3  QID294  Does your employer give you time to learn new ...
#
#             FORCE_RESP  TYPE SELECTOR
# qname
# S0               False    DB       TB
# ...

# %%
schema.rename(columns = {'QUESTION': 'Quiz'})
# Out:
#                 QID                                               Quiz  \
# qname
# S0            QID16  <div><span style="font-size:19px;"><strong>Hel...
# MetaInfo      QID12                                  Browser Meta Info
# S1             QID1  <span style="font-size:22px; font-family: aria...
# MainBranch     QID2  Which of the following options best describes ...
# Employment   QID296  Which of the following best describes your cur...
# ...             ...                                                ...
# Frequency_2  QID290  Interacting with people outside of your immedi...
# Frequency_3  QID290  Encountering knowledge silos (where one indivi...
# TrueFalse_1  QID294  Are you involved in supporting new hires durin...
# TrueFalse_2  QID294  Do you use learning resources provided by your...
# TrueFalse_3  QID294  Does your employer give you time to learn new ...
#
#             FORCE_RESP  TYPE SELECTOR
# qname
# S0               False    DB       TB
# ...

# %%
schema.columns = schema.columns.str.lower()

# %%
df.YearsCode.unique()
#Both below are the same
#df.YearsCode.replace(['More than 50 years', 'Less than 1 year'], [51, 0], inplace = True)
df['YearsCode'] = df.YearsCode.replace({'More than 50 years':51, 'Less than 1 year': 0})
df['YearsCode'] = df['YearsCode'].astype('float')
pd.Series.max(df['YearsCode'])
# Out:
# 51.0

# %%
schema.apply(len)
# Out:
# qid           79
# question      79
# force_resp    79
# type          79
# selector      79
# dtype: int64

# %%
df.drop(index = 0, inplace = True)
df['ResponseId'] = df['ResponseId'].apply(lambda x: x-1)
df
# Out:
#        ResponseId                                         MainBranch  \
# 1               1                     I am a developer by profession
# 2               2  I am not primarily a developer, but I write co...
# 3               3                     I am a developer by profession
# 4               4                     I am a developer by profession
# 5               5  I am not primarily a developer, but I write co...
# ...           ...                                                ...
# 73263       73263                     I am a developer by profession
# 73264       73264                     I am a developer by profession
# 73265       73265  I am not primarily a developer, but I write co...
# 73266       73266                     I am a developer by profession
# 73267       73267  I used to be a developer by profession, but no...
#
#                                               Employment  \
# 1                                    Employed, full-time
# ...

# %%
dict = {'qname': 'TrueFalse 3', 'qid':'QID294', 'question': 'Dont you see?', 'force_resp':np.nan,'type':'MC','selector':'MAVR'}
schema_new = schema.append(dict, ignore_index = True)
schema_new.set_index('qname')
# Out:
# C:\Users\locdu\AppData\Local\Temp\ipykernel_14560\3844252435.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   schema_new = schema.append(dict, ignore_index = True)
#                 qid                                           question  \
# qname
# NaN           QID16  <div><span style="font-size:19px;"><strong>Hel...
# NaN           QID12                                  Browser Meta Info
# NaN            QID1  <span style="font-size:22px; font-family: aria...
# NaN            QID2  Which of the following options best describes ...
# NaN          QID296  Which of the following best describes your cur...
# ...             ...                                                ...
# NaN          QID290  Encountering knowledge silos (where one indivi...
# NaN          QID294  Are you involved in supporting new hires durin...
# ...

# %%
schema_new.drop(columns=['force_resp','type', 'selector', 'qid'])
# Out:
#                                              question        qname
# 0   <div><span style="font-size:19px;"><strong>Hel...          NaN
# 1                                   Browser Meta Info          NaN
# 2   <span style="font-size:22px; font-family: aria...          NaN
# 3   Which of the following options best describes ...          NaN
# 4   Which of the following best describes your cur...          NaN
# ..                                                ...          ...
# 75  Encountering knowledge silos (where one indivi...          NaN
# 76  Are you involved in supporting new hires durin...          NaN
# 77  Do you use learning resources provided by your...          NaN
# 78  Does your employer give you time to learn new ...          NaN
# 79                                      Dont you see?  TrueFalse 3
#
# [80 rows x 2 columns]

# %%
df[['Gender', 'Sexuality']].sort_values(by = ['Gender', 'Sexuality'], ascending = True).head(4000)
# Out:
#      Gender          Sexuality
# 2       Man           Bisexual
# 16      Man           Bisexual
# 42      Man           Bisexual
# 49      Man           Bisexual
# 81      Man           Bisexual
# ...     ...                ...
# 8948    Man  Prefer not to say
# 8969    Man  Prefer not to say
# 9007    Man  Prefer not to say
# 9082    Man  Prefer not to say
# 9086    Man  Prefer not to say
#
# [4000 rows x 2 columns]

# %%
ctgrp = df.groupby('Country')
ctgrp['CompTotal'].nlargest(10).head(50)
# Out:
# Country
# Afghanistan  6891     5.500000e+07
#              38512    1.200000e+06
#              43639    7.000000e+05
#              43690    1.000000e+05
#              2448     4.000000e+04
#              6242     4.000000e+04
#              23223    4.000000e+04
#              49273    6.000000e+03
#              55665    2.000000e+02
#              3886     1.000000e+00
# Albania      33979    1.200000e+07
#              48375    4.000000e+05
#              8053     2.500000e+05
#              24580    2.500000e+05
#              25178    2.000000e+05
#              23138    1.800000e+05
#              42516    1.000000e+05
#              12747    8.000000e+04
#              21146    8.000000e+04
#              5621     6.000000e+04
# Algeria      6713     3.300000e+05
#              30328    9.500000e+04
#              6266     9.000000e+04
#              19840    8.000000e+04
#              50861    7.500000e+04
#              11326    5.500000e+04
# ...

# %%
schema.loc['PurchaseInfluence']['question']
# Out:
# 'What level of influence do you, personally, have over new technology purchases at your organization?'

# %%
df['CompTotal'].median()
# Out:
# 77500.0

# %%
df['CompTotal'].mean()
# Out:
# 2.342434022174796e+52

# %%
df['CompTotal'].describe()
# Out:
# count    3.842200e+04
# mean     2.342434e+52
# std      4.591478e+54
# min      0.000000e+00
# 25%      3.000000e+04
# 50%      7.750000e+04
# 75%      1.540000e+05
# max      9.000000e+56
# Name: CompTotal, dtype: float64

# %%
df['Country'].value_counts(normalize = True)
# Out:
# United States of America                                0.188697
# India                                                   0.092503
# Germany                                                 0.075170
# United Kingdom of Great Britain and Northern Ireland    0.058380
# Canada                                                  0.034694
#                                                           ...
# Monaco                                                  0.000014
# Djibouti                                                0.000014
# Seychelles                                              0.000014
# Solomon Islands                                         0.000014
# Saint Kitts and Nevis                                   0.000014
# Name: Country, Length: 180, dtype: float64

# %%
ctgrp[['Sexuality']].value_counts().tail(75)
# Out:
# Country                                               Sexuality
# United Kingdom of Great Britain and Northern Ireland  Prefer to self-describe:;Queer                                                        8
#                                                       Straight / Heterosexual;Prefer to self-describe:                                      6
#                                                       Gay or Lesbian;Queer                                                                  6
#                                                       Bisexual;Prefer to self-describe:;Queer                                               4
#                                                       Bisexual;Gay or Lesbian;Queer                                                         3
#                                                       Prefer to self-describe:;Gay or Lesbian                                               3
# ...

# %%
soa = df.groupby('SOAccount')
soa[['Country', 'SOAccount']].get_group('Yes').value_counts().head(50)
# Out:
# Country                                               SOAccount
# United States of America                              Yes          10682
# India                                                 Yes           5815
# Germany                                               Yes           4347
# United Kingdom of Great Britain and Northern Ireland  Yes           3364
# Canada                                                Yes           1954
# France                                                Yes           1838
# Brazil                                                Yes           1684
# Poland                                                Yes           1394
# Netherlands                                           Yes           1257
# Spain                                                 Yes           1234
# Italy                                                 Yes           1230
# Australia                                             Yes           1142
# ...

# %%
ctgrp['SOAccount'].value_counts().loc['Russian Federation']
# Out:
# SOAccount
# Yes                        986
# No                         167
# Not sure/can't remember     75
# Name: SOAccount, dtype: int64

# %%
a = ctgrp['CompTotal'].agg(['mean','median', 'min', 'max'])
a.loc['United States of America']
# Out:
# mean      1.138952e+48
# median    1.400000e+05
# min       0.000000e+00
# max       1.000000e+52
# Name: United States of America, dtype: float64

# %%
filt3 = df['Country'] == 'United States of America'
df.loc[filt3]['Sexuality'].str.contains('Gay', na = False).sum()
# Out:
# 465

# %%
b = ctgrp['Sexuality'].apply(lambda x: x.str.contains('Gay', na = False).sum())

# %%
c = df['Country'].value_counts()
d = pd.concat([c,b], axis = 'columns')
d['Gay_People_Percentage'] = d['Sexuality']/d['Country']*100
d.rename(columns = {'Country':'Total_Respondents', 'Sexuality': 'Number_of_Gay_People'})
# Out:
#                                                     Total_Respondents  \
# United States of America                                        13543
# India                                                            6639
# Germany                                                          5395
# United Kingdom of Great Britain and Northern Ir...               4190
# Canada                                                           2490
# ...                                                               ...
# Monaco                                                              1
# Djibouti                                                            1
# Seychelles                                                          1
# Solomon Islands                                                     1
# Saint Kitts and Nevis                                               1
#
#                                                     Number_of_Gay_People  \
# ...

# %%
d['Gay_People_Percentage'].mean()
# Out:
# 2.6113623601693754
