# %%
import pandas as pd
df = pd.read_csv('survey_results_public.csv')
pd.set_option('display.max_columns', 79)
df.head(3)
# Out:
#    ResponseId                                         MainBranch  \
# 0           1                                      None of these
# 1           2                     I am a developer by profession
# 2           3  I am not primarily a developer, but I write co...
#
#             Employment                            RemoteWork  \
# 0                  NaN                                   NaN
# 1  Employed, full-time                          Fully remote
# 2  Employed, full-time  Hybrid (some remote, some in-person)
#
#                            CodingActivities  \
# 0                                       NaN
# 1  Hobby;Contribute to open-source projects
# 2                                     Hobby
#
#                                            EdLevel  \
# 0                                              NaN
# 1                                              NaN
# 2  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
#
#                                            LearnCode  \
# ...

# %%
#df['ResponseId'] = df['ResponseId'].astype('string')
df1 = pd.concat([df['ResponseId'], df['LanguageHaveWorkedWith']], axis = 'columns')
df1
# Out:
#       ResponseId                             LanguageHaveWorkedWith
# 0              1                                                NaN
# 1              2                              JavaScript;TypeScript
# 2              3                  C#;C++;HTML/CSS;JavaScript;Python
# 3              4                       C#;JavaScript;SQL;TypeScript
# 4              5        C#;HTML/CSS;JavaScript;SQL;Swift;TypeScript
# ...          ...                                                ...
# 73263      73264  Bash/Shell;Dart;JavaScript;PHP;Python;SQL;Type...
# 73264      73265          Bash/Shell;HTML/CSS;JavaScript;Python;SQL
# 73265      73266                 HTML/CSS;JavaScript;PHP;Python;SQL
# 73266      73267                                      C#;Delphi;VBA
# 73267      73268        C#;JavaScript;Lua;PowerShell;SQL;TypeScript
#
# [73268 rows x 2 columns]

# %%
#df1.to_csv('data5.csv')

# %%
a = df.groupby('ResponseId')

# %%
a.get_group['LanguageHaveWorkedWith']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [18], in <cell line: 1>()
# ----> 1 a.get_group['LanguageHaveWorkedWith']
#
# TypeError: 'method' object is not subscriptable
